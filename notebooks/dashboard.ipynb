# %% [markdown]
# "This interactive dashboard focuses on crime data in the City of Chicago. Users can explore the distribution of different types of crimes across wards or community areas. The bar and line charts allow for a clear visualization of crime frequency and trends, helping to understand which areas are most affected and how crime patterns vary over time."

# %%
import dash
import pandas as pd
import plotly.express as px
from dash.dependencies import Input, Output
from dash import dcc,html

# %%
# Load the dataset
crime_df=pd.read_csv('data/chicago_crime_clean.csv')

# %%
# Creata the application
app=dash.Dash(__name__)

# %%
# The application layout
app.layout=html.Div([
    html.H1('Chicago Crime Dashboard', style={'textAlign':'center','font-size':30}),
    html.Br(),
    html.Div([
        html.H2('Select Crime Type:'),
        dcc.Dropdown(
            id='crime-dropdown',
            options=[{'label':c,'value':c} for c in crime_df['PRIMARY_TYPE'].unique()],
            value=crime_df['PRIMARY_TYPE'].unique()[0]
        ),
        html.H2('Select Aggregation: '),
        dcc.RadioItems(
            id='agg-radio',
            options=[
                {'label':'ward','value':'WARD'},
                {'label':'community_number','value':'community_number'}
            ],
            value='WARD',
            inline=True
        ),
        html.Div([
            html.Div([
                dcc.Graph(id='bar-plot')
            ]),
            html.Div([
                dcc.Graph(id='line-plot')
            ])
        ],style={'display':'flex'})
        
    ])
])

# Callback
@app.callback([
    Output('bar-plot','figure'),
    Output('line-plot','figure')
],
             [
                 Input('crime-dropdown','value'),
                 Input('agg-radio','value')
             ])

def update_graph(selected_crime,selected_agg):
    filtered_df=crime_df[crime_df['PRIMARY_TYPE']==selected_crime]
    bar_fig=px.bar(
        filtered_df.groupby(selected_agg).size().reset_index(name='Count'),
        x=selected_agg,
        y='Count',
        title=f"Number of {selected_crime} crimes by {selected_agg}"
    )
    line_fig=px.line(
        filtered_df.groupby('YEAR').size().reset_index(name='Count'),
        x='YEAR',
        y='Count',
        title=f"Yearly Evolution of {selected_crime} crime"
    )
    return bar_fig,line_fig

# Run Server
if __name__=='__main__':
    app.run(debug=True, port=8051)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[9], line 62
#      60 # Run Server
#      61 if __name__=='__main__':
# ---> 62     app.run(debug=True, port=8051)
#
# File E:\viz_ana\ana_env\Lib\site-packages\dash\dash.py:2399, in Dash.run(self, host, port, proxy, debug, jupyter_mode, jupyter_width, jupyter_height, jupyter_server_url, dev_tools_ui, dev_tools_props_check, dev_tools_serve_dev_bundles, dev_tools_hot_reload, dev_tools_hot_reload_interval, dev_tools_hot_reload_watch_interval, dev_tools_hot_reload_max_retry, dev_tools_silence_routes_logging, dev_tools_disable_version_check, dev_tools_prune_errors, **flask_run_options)
#    2396 if debug is None:
#    2397     debug = get_combined_config("debug", None, False)
# -> 2399 debug = self.enable_dev_tools(
#    2400     debug,
#    2401     dev_tools_ui,
#    2402     dev_tools_props_check,
#    2403     dev_tools_serve_dev_bundles,
#    2404     dev_tools_hot_reload,
#    2405     dev_tools_hot_reload_interval,
#    2406     dev_tools_hot_reload_watch_interval,
#    2407     dev_tools_hot_reload_max_retry,
#    2408     dev_tools_silence_routes_logging,
#    2409     dev_tools_disable_version_check,
#    2410     dev_tools_prune_errors,
#    2411 )
#    2413 # Evaluate the env variables at runtime
#    2415 if "CONDA_PREFIX" in os.environ:
#    2416     # Some conda systems has issue with setting the host environment
#    2417     # to an invalid hostname.
#    2418     # Related issue: https://github.com/plotly/dash/issues/3069
#
# File E:\viz_ana\ana_env\Lib\site-packages\dash\dash.py:2162, in Dash.enable_dev_tools(self, debug, dev_tools_ui, dev_tools_props_check, dev_tools_serve_dev_bundles, dev_tools_hot_reload, dev_tools_hot_reload_interval, dev_tools_hot_reload_watch_interval, dev_tools_hot_reload_max_retry, dev_tools_silence_routes_logging, dev_tools_disable_version_check, dev_tools_prune_errors)
#    2160 if debug:
#    2161     if jupyter_dash.active:
# -> 2162         jupyter_dash.configure_callback_exception_handling(
#    2163             self, dev_tools.prune_errors
#    2164         )
#    2165     elif dev_tools.prune_errors:
#    2166         secret = gen_salt(20)
#
# File E:\viz_ana\ana_env\Lib\site-packages\dash\_jupyter.py:517, in JupyterDash.configure_callback_exception_handling(self, app, dev_tools_prune_errors)
#     514 def configure_callback_exception_handling(self, app, dev_tools_prune_errors):
#     515     """Install traceback handling for callbacks"""
# --> 517     @app.server.errorhandler(Exception)
#     518     def _wrap_errors(error):
#     519         # Compute number of stack frames to skip to get down to callback
#     520         skip = _get_skip(error) if dev_tools_prune_errors else 0
#     522         # Customized formatargvalues function we can place function parameters
#     523         # on separate lines
#
# File E:\viz_ana\ana_env\Lib\site-packages\flask\sansio\scaffold.py:46, in setupmethod.<locals>.wrapper_func(self, *args, **kwargs)
#      45 def wrapper_func(self: Scaffold, *args: t.Any, **kwargs: t.Any) -> t.Any:
# ---> 46     self._check_setup_finished(f_name)
#      47     return f(self, *args, **kwargs)
#
# File E:\viz_ana\ana_env\Lib\site-packages\flask\sansio\app.py:415, in App._check_setup_finished(self, f_name)
#     413 def _check_setup_finished(self, f_name: str) -> None:
#     414     if self._got_first_request:
# --> 415         raise AssertionError(
#     416             f"The setup method '{f_name}' can no longer be called"
#     417             " on the application. It has already handled its first"
#     418             " request, any changes will not be applied"
#     419             " consistently.\n"
#     420             "Make sure all imports, decorators, functions, etc."
#     421             " needed to set up the application are done before"
#     422             " running it."
#     423         )
#
# AssertionError: The setup method 'errorhandler' can no longer be called on the application. It has already handled its first request, any changes will not be applied consistently.
# Make sure all imports, decorators, functions, etc. needed to set up the application are done before running it.
